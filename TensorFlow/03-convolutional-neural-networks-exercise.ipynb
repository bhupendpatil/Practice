# %% [markdown]
# # 🛠 03 Computer vision & convolutional neural networks in TensorFlow Exercises
# 3. Take 10 photos of two different things and build your own CNN image classifier using the techniques we've built here.
# 4. Find an ideal learning rate for a simple convolutional neural network model on your the 10 class dataset.

# %% [markdown]
# ## 3. Take 10 photos of two different things and build your own CNN image classifier using the techniques we've built here.

# %%
# !rm -rf *
# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip

import zipfile
zip_ref = zipfile.ZipFile("pizza_steak.zip")
zip_ref.extractall()
zip_ref.close()

# !mkdir train
# !mkdir test

# Pizza
## train
# !mkdir train/pizza
# !mv -f pizza_steak/train/pizza/2965.jpg train/pizza
# !mv -f pizza_steak/train/pizza/5764.jpg train/pizza
# !mv -f pizza_steak/train/pizza/8917.jpg train/pizza
# !mv -f pizza_steak/train/pizza/12301.jpg train/pizza
# !mv -f pizza_steak/train/pizza/12718.jpg train/pizza
# !mv -f pizza_steak/train/pizza/13983.jpg train/pizza
# !mv -f pizza_steak/train/pizza/23199.jpg train/pizza
# !mv -f pizza_steak/train/pizza/27963.jpg train/pizza
# !mv -f pizza_steak/train/pizza/29417.jpg train/pizza
# !mv -f pizza_steak/train/pizza/32004.jpg train/pizza

## test
# !mkdir test/pizza
# !mv -f pizza_steak/test/pizza/11297.jpg test/pizza
# !mv -f pizza_steak/test/pizza/22489.jpg test/pizza
# !mv -f pizza_steak/test/pizza/40449.jpg test/pizza
# !mv -f pizza_steak/test/pizza/44810.jpg test/pizza
# !mv -f pizza_steak/test/pizza/53217.jpg test/pizza

# Steak
## train
# !mkdir train/steak
# !mv -f pizza_steak/train/steak/3136.jpg train/steak
# !mv -f pizza_steak/train/steak/4176.jpg train/steak
# !mv -f pizza_steak/train/steak/6709.jpg train/steak
# !mv -f pizza_steak/train/steak/6926.jpg train/steak
# !mv -f pizza_steak/train/steak/9555.jpg train/steak
# !mv -f pizza_steak/train/steak/10380.jpg train/steak
# !mv -f pizza_steak/train/steak/15580.jpg train/steak
# !mv -f pizza_steak/train/steak/22080.jpg train/steak
# !mv -f pizza_steak/train/steak/31881.jpg train/steak
# !mv -f pizza_steak/train/steak/32693.jpg train/steak

## test
# !mkdir test/steak
# !mv -f pizza_steak/test/steak/4889.jpg test/steak
# !mv -f pizza_steak/test/steak/6261.jpg test/steak
# !mv -f pizza_steak/test/steak/7056.jpg test/steak
# !mv -f pizza_steak/test/steak/13023.jpg test/steak
# !mv -f pizza_steak/test/steak/13719.jpg test/steak

# remove extra data
# !rm -r __MACOSX
# !rm -r pizza_steak
# !rm -r pizza_steak.zip
# Out:
# --2021-05-31 14:24:59--  https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.176.128, 173.194.219.128, 108.177.122.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.176.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109579078 (105M) [application/zip]
# Saving to: ‘pizza_steak.zip’
#
# pizza_steak.zip     100%[===================>] 104.50M   167MB/s    in 0.6s
#
# 2021-05-31 14:25:00 (167 MB/s) - ‘pizza_steak.zip’ saved [109579078/109579078]

# %%
# Class names
import pathlib
import numpy as np
data_dir = pathlib.Path("train")
class_names = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_names)
# Out:
# ['pizza' 'steak']

# %%
# build CNN classifier 
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# preprocess data
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Set dir path
train_dir = "train"
test_dir = "test"

# Import data from directories
train_data = train_datagen.flow_from_directory(directory=train_dir,
                                              batch_size=32,
                                              target_size=(224,224),
                                              class_mode="binary")

test_data = test_datagen.flow_from_directory(directory=test_dir,
                                              batch_size=32,
                                              target_size=(224,224),
                                              class_mode="binary")

# Create a model
model_1 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(10,3,activation="relu",input_shape=(224,224,3)),
    tf.keras.layers.Conv2D(10,3,activation="relu"),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Conv2D(10,3,activation="relu"),
    tf.keras.layers.Conv2D(10,3,activation="relu"),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1,activation="sigmoid")
])

# Compile model
model_1.compile(loss="binary_crossentropy",
               optimizer=tf.keras.optimizers.Adam(),
               metrics=["accuracy"])

# Fit model
history_1 = model_1.fit(train_data,
                       epochs=5,
                       steps_per_epoch=len(train_data),
                       validation_data=test_data,
                       validation_steps=len(test_data))
# Out:
# Found 20 images belonging to 2 classes.
# Found 10 images belonging to 2 classes.
# Epoch 1/5
# 1/1 [==============================] - 5s 5s/step - loss: 0.6988 - accuracy: 0.5000 - val_loss: 1.9518 - val_accuracy: 0.5000
# Epoch 2/5
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 3.3366 - val_accuracy: 0.5000
# Epoch 3/5
# 1/1 [==============================] - 0s 200ms/step - loss: 2.9751 - accuracy: 0.5000 - val_loss: 1.9103 - val_accuracy: 0.5000
# Epoch 4/5
# 1/1 [==============================] - 0s 196ms/step - loss: 1.7138 - accuracy: 0.5000 - val_loss: 0.8076 - val_accuracy: 0.5000
# Epoch 5/5
# 1/1 [==============================] - 0s 192ms/step - loss: 0.7678 - accuracy: 0.5000 - val_loss: 0.8828 - val_accuracy: 0.5000

# %%
model_1.evaluate(test_data)
# Out:
# 1/1 [==============================] - 0s 69ms/step - loss: 0.8828 - accuracy: 0.5000
# [0.8827548027038574, 0.5]

# %% [markdown]
# ## 4. Find an ideal learning rate for a simple convolutional neural network model on your the 10 class dataset.

# %%
# Create ImageDataGenerator training instance with data augmentation
train_datagen_augmented = ImageDataGenerator(rescale=1/255.,
                                            rotation_range=0.2,
                                            zoom_range=0.2,
                                            width_shift_range=0.2,
                                            height_shift_range=0.3,
                                            horizontal_flip=True)

# Import data and augment it from training directory
train_data_augmented = train_datagen_augmented.flow_from_directory(train_dir,
                                                                  target_size=(224,224),
                                                                  batch_size=32,
                                                                  class_mode="binary")
# Out:
# Found 20 images belonging to 2 classes.

# %%
# Create a model
model_2 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(10,3,activation="relu",input_shape=(224,224,3)),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Conv2D(10,3,activation="relu"),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1,activation="sigmoid")
])

# Compile model
model_2.compile(loss="binary_crossentropy",
               optimizer=tf.keras.optimizers.Adam(),
               metrics=["accuracy"])

# Fit model
history_2 = model_2.fit(train_data_augmented,
                       epochs=100,
                       steps_per_epoch=len(train_data_augmented),
                       validation_data=test_data,
                       validation_steps=len(test_data))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 842ms/step - loss: 0.6857 - accuracy: 0.6500 - val_loss: 0.6688 - val_accuracy: 0.5000
# Epoch 2/100
# 1/1 [==============================] - 0s 333ms/step - loss: 0.6710 - accuracy: 0.5000 - val_loss: 0.6567 - val_accuracy: 0.7000
# Epoch 3/100
# 1/1 [==============================] - 0s 322ms/step - loss: 0.6499 - accuracy: 0.6500 - val_loss: 0.6284 - val_accuracy: 0.7000
# Epoch 4/100
# 1/1 [==============================] - 0s 326ms/step - loss: 0.6466 - accuracy: 0.6500 - val_loss: 0.6442 - val_accuracy: 0.6000
# Epoch 5/100
# 1/1 [==============================] - 0s 338ms/step - loss: 0.6549 - accuracy: 0.5000 - val_loss: 0.6124 - val_accuracy: 0.7000
# Epoch 6/100
# 1/1 [==============================] - 0s 331ms/step - loss: 0.5836 - accuracy: 0.7500 - val_loss: 0.5915 - val_accuracy: 0.7000
# Epoch 7/100
# 1/1 [==============================] - 0s 432ms/step - loss: 0.5809 - accuracy: 0.8000 - val_loss: 0.5860 - val_accuracy: 0.6000
# Epoch 8/100
# 1/1 [==============================] - 0s 401ms/step - loss: 0.5524 - accuracy: 0.8500 - val_loss: 0.5845 - val_accuracy: 0.7000
# Epoch 9/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.5352 - accuracy: 0.7000 - val_loss: 0.5922 - val_accuracy: 0.7000
# Epoch 10/100
# 1/1 [==============================] - 0s 327ms/step - loss: 0.5331 - accuracy: 0.7500 - val_loss: 0.5863 - val_accuracy: 0.7000
# Epoch 11/100
# 1/1 [==============================] - 0s 322ms/step - loss: 0.5275 - accuracy: 0.7500 - val_loss: 0.5759 - val_accuracy: 0.7000
# Epoch 12/100
# 1/1 [==============================] - 0s 314ms/step - loss: 0.4619 - accuracy: 0.8000 - val_loss: 0.5747 - val_accuracy: 0.7000
# Epoch 13/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.5046 - accuracy: 0.8500 - val_loss: 0.5767 - val_accuracy: 0.7000
# Epoch 14/100
# 1/1 [==============================] - 0s 327ms/step - loss: 0.4151 - accuracy: 0.9000 - val_loss: 0.5853 - val_accuracy: 0.6000
# Epoch 15/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.4693 - accuracy: 0.8500 - val_loss: 0.6471 - val_accuracy: 0.6000
# Epoch 16/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.4657 - accuracy: 0.8500 - val_loss: 0.6612 - val_accuracy: 0.6000
# Epoch 17/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.5260 - accuracy: 0.8000 - val_loss: 0.5943 - val_accuracy: 0.6000
# Epoch 18/100
# 1/1 [==============================] - 0s 342ms/step - loss: 0.5667 - accuracy: 0.7500 - val_loss: 0.5942 - val_accuracy: 0.6000
# Epoch 19/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.5379 - accuracy: 0.8000 - val_loss: 0.6019 - val_accuracy: 0.7000
# Epoch 20/100
# 1/1 [==============================] - 0s 333ms/step - loss: 0.4037 - accuracy: 0.9000 - val_loss: 0.6125 - val_accuracy: 0.7000
# Epoch 21/100
# 1/1 [==============================] - 0s 327ms/step - loss: 0.4910 - accuracy: 0.8000 - val_loss: 0.6201 - val_accuracy: 0.7000
# Epoch 22/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.3661 - accuracy: 0.8500 - val_loss: 0.6178 - val_accuracy: 0.7000
# Epoch 23/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.3772 - accuracy: 0.8500 - val_loss: 0.6023 - val_accuracy: 0.8000
# Epoch 24/100
# 1/1 [==============================] - 0s 331ms/step - loss: 0.3272 - accuracy: 0.8000 - val_loss: 0.6251 - val_accuracy: 0.6000
# Epoch 25/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.4664 - accuracy: 0.7000 - val_loss: 0.6067 - val_accuracy: 0.7000
# Epoch 26/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.4006 - accuracy: 0.8000 - val_loss: 0.7237 - val_accuracy: 0.5000
# Epoch 27/100
# 1/1 [==============================] - 0s 319ms/step - loss: 0.4245 - accuracy: 0.8000 - val_loss: 0.8819 - val_accuracy: 0.6000
# Epoch 28/100
# 1/1 [==============================] - 0s 321ms/step - loss: 0.6001 - accuracy: 0.7000 - val_loss: 0.7312 - val_accuracy: 0.6000
# Epoch 29/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.4065 - accuracy: 0.8000 - val_loss: 0.5864 - val_accuracy: 0.7000
# Epoch 30/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.5520 - accuracy: 0.7000 - val_loss: 0.5740 - val_accuracy: 0.7000
# Epoch 31/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.4161 - accuracy: 0.8500 - val_loss: 0.5536 - val_accuracy: 0.7000
# Epoch 32/100
# 1/1 [==============================] - 0s 317ms/step - loss: 0.5286 - accuracy: 0.7000 - val_loss: 0.5692 - val_accuracy: 0.7000
# Epoch 33/100
# 1/1 [==============================] - 0s 317ms/step - loss: 0.4005 - accuracy: 0.8500 - val_loss: 0.7354 - val_accuracy: 0.6000
# Epoch 34/100
# 1/1 [==============================] - 0s 321ms/step - loss: 0.5150 - accuracy: 0.7500 - val_loss: 0.7594 - val_accuracy: 0.6000
# Epoch 35/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.4927 - accuracy: 0.7500 - val_loss: 0.5777 - val_accuracy: 0.8000
# Epoch 36/100
# 1/1 [==============================] - 0s 326ms/step - loss: 0.4398 - accuracy: 0.8000 - val_loss: 0.4834 - val_accuracy: 0.8000
# Epoch 37/100
# 1/1 [==============================] - 0s 326ms/step - loss: 0.3395 - accuracy: 0.9000 - val_loss: 0.4644 - val_accuracy: 0.8000
# Epoch 38/100
# 1/1 [==============================] - 0s 322ms/step - loss: 0.3444 - accuracy: 0.8000 - val_loss: 0.4756 - val_accuracy: 0.7000
# Epoch 39/100
# 1/1 [==============================] - 0s 477ms/step - loss: 0.3934 - accuracy: 0.8500 - val_loss: 0.5449 - val_accuracy: 0.8000
# Epoch 40/100
# 1/1 [==============================] - 0s 376ms/step - loss: 0.2984 - accuracy: 0.9500 - val_loss: 0.5886 - val_accuracy: 0.8000
# Epoch 41/100
# 1/1 [==============================] - 0s 319ms/step - loss: 0.2633 - accuracy: 0.9500 - val_loss: 0.5422 - val_accuracy: 0.8000
# Epoch 42/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.3546 - accuracy: 0.9000 - val_loss: 0.4683 - val_accuracy: 0.7000
# Epoch 43/100
# 1/1 [==============================] - 0s 333ms/step - loss: 0.5696 - accuracy: 0.7000 - val_loss: 0.4690 - val_accuracy: 0.7000
# Epoch 44/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.3873 - accuracy: 0.8500 - val_loss: 0.4766 - val_accuracy: 0.7000
# Epoch 45/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.2713 - accuracy: 0.9000 - val_loss: 0.5047 - val_accuracy: 0.7000
# Epoch 46/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.2902 - accuracy: 0.9500 - val_loss: 0.5152 - val_accuracy: 0.7000
# Epoch 47/100
# 1/1 [==============================] - 0s 333ms/step - loss: 0.4333 - accuracy: 0.8000 - val_loss: 0.5156 - val_accuracy: 0.7000
# Epoch 48/100
# 1/1 [==============================] - 0s 317ms/step - loss: 0.3804 - accuracy: 0.8500 - val_loss: 0.5217 - val_accuracy: 0.8000
# Epoch 49/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.4080 - accuracy: 0.8000 - val_loss: 0.5363 - val_accuracy: 0.8000
# Epoch 50/100
# 1/1 [==============================] - 0s 321ms/step - loss: 0.2840 - accuracy: 0.9000 - val_loss: 0.5069 - val_accuracy: 0.8000
# Epoch 51/100
# 1/1 [==============================] - 0s 321ms/step - loss: 0.2533 - accuracy: 0.9000 - val_loss: 0.4528 - val_accuracy: 0.7000
# Epoch 52/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.3617 - accuracy: 0.9000 - val_loss: 0.4354 - val_accuracy: 0.7000
# Epoch 53/100
# 1/1 [==============================] - 0s 321ms/step - loss: 0.2816 - accuracy: 0.9500 - val_loss: 0.4360 - val_accuracy: 0.7000
# Epoch 54/100
# 1/1 [==============================] - 0s 322ms/step - loss: 0.2230 - accuracy: 0.9000 - val_loss: 0.4624 - val_accuracy: 0.8000
# Epoch 55/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.2872 - accuracy: 0.9000 - val_loss: 0.4749 - val_accuracy: 0.8000
# Epoch 56/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.2631 - accuracy: 0.9000 - val_loss: 0.4822 - val_accuracy: 0.8000
# Epoch 57/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.2795 - accuracy: 0.9500 - val_loss: 0.4645 - val_accuracy: 0.8000
# Epoch 58/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.2370 - accuracy: 1.0000 - val_loss: 0.4383 - val_accuracy: 0.7000
# Epoch 59/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.2274 - accuracy: 0.9500 - val_loss: 0.4399 - val_accuracy: 0.7000
# Epoch 60/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.3399 - accuracy: 0.8500 - val_loss: 0.4498 - val_accuracy: 0.7000
# Epoch 61/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.2264 - accuracy: 0.9000 - val_loss: 0.5311 - val_accuracy: 0.8000
# Epoch 62/100
# 1/1 [==============================] - 0s 334ms/step - loss: 0.3576 - accuracy: 0.8000 - val_loss: 0.5435 - val_accuracy: 0.8000
# Epoch 63/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.2852 - accuracy: 0.9500 - val_loss: 0.4683 - val_accuracy: 0.7000
# Epoch 64/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.2525 - accuracy: 0.9000 - val_loss: 0.4828 - val_accuracy: 0.7000
# Epoch 65/100
# 1/1 [==============================] - 0s 405ms/step - loss: 0.2792 - accuracy: 0.8000 - val_loss: 0.4817 - val_accuracy: 0.6000
# Epoch 66/100
# 1/1 [==============================] - 1s 528ms/step - loss: 0.3381 - accuracy: 0.8000 - val_loss: 0.5414 - val_accuracy: 0.8000
# Epoch 67/100
# 1/1 [==============================] - 0s 423ms/step - loss: 0.2234 - accuracy: 0.9000 - val_loss: 0.6831 - val_accuracy: 0.8000
# Epoch 68/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.1845 - accuracy: 1.0000 - val_loss: 0.6701 - val_accuracy: 0.8000
# Epoch 69/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.2681 - accuracy: 0.9000 - val_loss: 0.4980 - val_accuracy: 0.7000
# Epoch 70/100
# 1/1 [==============================] - 1s 560ms/step - loss: 0.3643 - accuracy: 0.7500 - val_loss: 0.6415 - val_accuracy: 0.7000
# Epoch 71/100
# 1/1 [==============================] - 0s 331ms/step - loss: 0.3213 - accuracy: 0.8500 - val_loss: 0.5386 - val_accuracy: 0.8000
# Epoch 72/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.1771 - accuracy: 0.9000 - val_loss: 0.4973 - val_accuracy: 0.7000
# Epoch 73/100
# 1/1 [==============================] - 0s 339ms/step - loss: 0.2245 - accuracy: 0.9500 - val_loss: 0.6082 - val_accuracy: 0.8000
# Epoch 74/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.1835 - accuracy: 0.9500 - val_loss: 0.6188 - val_accuracy: 0.8000
# Epoch 75/100
# 1/1 [==============================] - 0s 349ms/step - loss: 0.1983 - accuracy: 0.9500 - val_loss: 0.4992 - val_accuracy: 0.7000
# Epoch 76/100
# 1/1 [==============================] - 0s 338ms/step - loss: 0.1226 - accuracy: 1.0000 - val_loss: 0.4764 - val_accuracy: 0.8000
# Epoch 77/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.1237 - accuracy: 1.0000 - val_loss: 0.5119 - val_accuracy: 0.7000
# Epoch 78/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.1667 - accuracy: 0.9500 - val_loss: 0.4781 - val_accuracy: 0.7000
# Epoch 79/100
# 1/1 [==============================] - 0s 341ms/step - loss: 0.1587 - accuracy: 0.9500 - val_loss: 0.4861 - val_accuracy: 0.7000
# Epoch 80/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.1709 - accuracy: 0.9500 - val_loss: 0.6645 - val_accuracy: 0.7000
# Epoch 81/100
# 1/1 [==============================] - 0s 338ms/step - loss: 0.1944 - accuracy: 0.9500 - val_loss: 0.6732 - val_accuracy: 0.7000
# Epoch 82/100
# 1/1 [==============================] - 0s 337ms/step - loss: 0.2055 - accuracy: 0.9000 - val_loss: 0.5937 - val_accuracy: 0.8000
# Epoch 83/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.1606 - accuracy: 0.9000 - val_loss: 0.4997 - val_accuracy: 0.7000
# Epoch 84/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.1317 - accuracy: 0.9500 - val_loss: 0.4858 - val_accuracy: 0.7000
# Epoch 85/100
# 1/1 [==============================] - 0s 340ms/step - loss: 0.2673 - accuracy: 0.9000 - val_loss: 0.4882 - val_accuracy: 0.7000
# Epoch 86/100
# 1/1 [==============================] - 0s 337ms/step - loss: 0.1221 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.7000
# Epoch 87/100
# 1/1 [==============================] - 0s 333ms/step - loss: 0.1246 - accuracy: 0.9500 - val_loss: 0.4763 - val_accuracy: 0.7000
# Epoch 88/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.1581 - accuracy: 1.0000 - val_loss: 0.4991 - val_accuracy: 0.7000
# Epoch 89/100
# 1/1 [==============================] - 0s 327ms/step - loss: 0.1308 - accuracy: 0.9500 - val_loss: 0.5212 - val_accuracy: 0.8000
# Epoch 90/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.1679 - accuracy: 0.9500 - val_loss: 0.5564 - val_accuracy: 0.8000
# Epoch 91/100
# 1/1 [==============================] - 0s 327ms/step - loss: 0.2287 - accuracy: 0.9500 - val_loss: 0.4753 - val_accuracy: 0.8000
# Epoch 92/100
# 1/1 [==============================] - 0s 325ms/step - loss: 0.1072 - accuracy: 1.0000 - val_loss: 0.4418 - val_accuracy: 0.7000
# Epoch 93/100
# 1/1 [==============================] - 0s 321ms/step - loss: 0.3012 - accuracy: 0.8500 - val_loss: 0.4383 - val_accuracy: 0.7000
# Epoch 94/100
# 1/1 [==============================] - 0s 321ms/step - loss: 0.1320 - accuracy: 0.9500 - val_loss: 0.4442 - val_accuracy: 0.8000
# Epoch 95/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.1786 - accuracy: 0.9500 - val_loss: 0.4602 - val_accuracy: 0.7000
# Epoch 96/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.1051 - accuracy: 1.0000 - val_loss: 0.4962 - val_accuracy: 0.7000
# Epoch 97/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.1576 - accuracy: 0.9000 - val_loss: 0.5155 - val_accuracy: 0.7000
# Epoch 98/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.0920 - accuracy: 1.0000 - val_loss: 0.5177 - val_accuracy: 0.7000
# Epoch 99/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.1481 - accuracy: 0.9500 - val_loss: 0.5297 - val_accuracy: 0.7000
# Epoch 100/100
# 1/1 [==============================] - 0s 326ms/step - loss: 0.1822 - accuracy: 0.9000 - val_loss: 0.6268 - val_accuracy: 0.7000

# %%
model_2.evaluate(test_data)
# Out:
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6268 - accuracy: 0.7000
# [0.6267704963684082, 0.699999988079071]
