# %% [markdown]
# # Improving Computer Vision Accuracy using Convolutions
#
# In previous lessons you saw how to do image recognition using a Deep Neural Network (DNN) containing three layers -- the input layer (in the shape of the data), the output layer (in the shape of the desired output) and a hidden layer.
# For convenience, here's the entire code again. Run it and take a note of the accuracy that is printed out at the end.

# %%
import tensorflow as tf
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (val_images, val_labels) = mnist.load_data()
training_images=training_images / 255.0
val_images=val_images / 255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(20, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(training_images, training_labels, validation_data=(val_images, val_labels), epochs=20)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# Epoch 1/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.8020 - accuracy: 0.7274 - val_loss: 0.4822 - val_accuracy: 0.8284
# Epoch 2/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4313 - accuracy: 0.8492 - val_loss: 0.4425 - val_accuracy: 0.8454
# Epoch 3/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4020 - accuracy: 0.8600 - val_loss: 0.4334 - val_accuracy: 0.8443
# Epoch 4/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3749 - accuracy: 0.8665 - val_loss: 0.4276 - val_accuracy: 0.8511
# Epoch 5/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3627 - accuracy: 0.8720 - val_loss: 0.3996 - val_accuracy: 0.8576
# Epoch 6/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3449 - accuracy: 0.8762 - val_loss: 0.3987 - val_accuracy: 0.8595
# Epoch 7/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3380 - accuracy: 0.8788 - val_loss: 0.3956 - val_accuracy: 0.8615
# Epoch 8/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3379 - accuracy: 0.8795 - val_loss: 0.3987 - val_accuracy: 0.8574
# Epoch 9/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3237 - accuracy: 0.8834 - val_loss: 0.3938 - val_accuracy: 0.8624
# Epoch 10/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3134 - accuracy: 0.8865 - val_loss: 0.3968 - val_accuracy: 0.8622
# Epoch 11/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3119 - accuracy: 0.8871 - val_loss: 0.3822 - val_accuracy: 0.8679
# Epoch 12/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3038 - accuracy: 0.8884 - val_loss: 0.3862 - val_accuracy: 0.8645
# Epoch 13/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3043 - accuracy: 0.8917 - val_loss: 0.3945 - val_accuracy: 0.8586
# Epoch 14/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3024 - accuracy: 0.8909 - val_loss: 0.3819 - val_accuracy: 0.8662
# Epoch 15/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2981 - accuracy: 0.8922 - val_loss: 0.3980 - val_accuracy: 0.8584
# Epoch 16/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2930 - accuracy: 0.8922 - val_loss: 0.3870 - val_accuracy: 0.8679
# Epoch 17/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2832 - accuracy: 0.8978 - val_loss: 0.4121 - val_accuracy: 0.8512
# Epoch 18/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2893 - accuracy: 0.8968 - val_loss: 0.3813 - val_accuracy: 0.8685
# Epoch 19/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2839 - accuracy: 0.8960 - val_loss: 0.3880 - val_accuracy: 0.8645
# Epoch 20/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2854 - accuracy: 0.8973 - val_loss: 0.3935 - val_accuracy: 0.8626

# %% [markdown]
# Your accuracy is probably about 89% on training and 87% on validation...not bad...But how do you make that even better? One way is to use something called Convolutions. I'm not going to get into the details of Convolutions here, but the ultimate concept is that they narrow down the content of the image to focus on specific, distinct, features.
#
# If you've ever done image processing using a filter (like this: https://en.wikipedia.org/wiki/Kernel_(image_processing)) then convolutions will look very familiar.
#
# In short, you take an array (usually 3x3 or 5x5) and pass it over the image. By changing the underlying pixels based on the formula within that matrix, you can do things like edge detection. So, for example, if you look at the above link, you'll see a 3x3 that is defined for edge detection where the middle cell is 8, and all of its neighbors are -1. In this case, for each pixel, you would multiply its value by 8, then subtract the value of each neighbor. Do this for every pixel, and you'll end up with a new image that has the edges enhanced.
#
# This is perfect for computer vision, because often it's features like edges that distinguish one item for another. And once we move from raw image data to feature data, the amount of information needed is then much less...because you'll just train on the highlighted features.
#
# That's the concept of Convolutional Neural Networks. Add some layers to do convolution before you have the dense layers, and then the information going to the dense layers is more focussed, and possibly more accurate.
#
# Run the below code -- this is the same neural network as earlier, but this time with Convolutional layers added first. It will take longer, but look at the impact on the accuracy:

# %%
import tensorflow as tf
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (val_images, val_labels) = mnist.load_data()
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0
val_images=val_images.reshape(10000, 28, 28, 1)
val_images=val_images/255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(20, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(training_images, training_labels, validation_data=(val_images, val_labels), epochs=100)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                32020
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                210
# =================================================================
# Total params: 69,798
# Trainable params: 69,798
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1875/1875 [==============================] - 9s 2ms/step - loss: 0.6764 - accuracy: 0.7574 - val_loss: 0.3689 - val_accuracy: 0.8676
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3395 - accuracy: 0.8783 - val_loss: 0.3311 - val_accuracy: 0.8788
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2848 - accuracy: 0.8959 - val_loss: 0.2876 - val_accuracy: 0.8952
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2544 - accuracy: 0.9101 - val_loss: 0.2808 - val_accuracy: 0.8994
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2282 - accuracy: 0.9167 - val_loss: 0.2809 - val_accuracy: 0.8967
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2100 - accuracy: 0.9257 - val_loss: 0.2842 - val_accuracy: 0.8969
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1920 - accuracy: 0.9306 - val_loss: 0.2742 - val_accuracy: 0.9010
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1800 - accuracy: 0.9350 - val_loss: 0.2589 - val_accuracy: 0.9099
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1661 - accuracy: 0.9400 - val_loss: 0.2638 - val_accuracy: 0.9082
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1502 - accuracy: 0.9455 - val_loss: 0.2773 - val_accuracy: 0.9026
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1433 - accuracy: 0.9474 - val_loss: 0.2835 - val_accuracy: 0.9083
# Epoch 12/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1305 - accuracy: 0.9524 - val_loss: 0.2932 - val_accuracy: 0.9045
# Epoch 13/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1212 - accuracy: 0.9547 - val_loss: 0.2882 - val_accuracy: 0.9113
# Epoch 14/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1135 - accuracy: 0.9581 - val_loss: 0.3086 - val_accuracy: 0.9014
# Epoch 15/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1055 - accuracy: 0.9612 - val_loss: 0.3215 - val_accuracy: 0.9057
# Epoch 16/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0998 - accuracy: 0.9632 - val_loss: 0.3254 - val_accuracy: 0.9013
# Epoch 17/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0916 - accuracy: 0.9656 - val_loss: 0.3226 - val_accuracy: 0.9067
# Epoch 18/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0899 - accuracy: 0.9675 - val_loss: 0.3342 - val_accuracy: 0.9074
# Epoch 19/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0752 - accuracy: 0.9728 - val_loss: 0.3497 - val_accuracy: 0.9022
# Epoch 20/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0794 - accuracy: 0.9712 - val_loss: 0.3680 - val_accuracy: 0.9036
# Epoch 21/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0741 - accuracy: 0.9716 - val_loss: 0.3747 - val_accuracy: 0.9071
# Epoch 22/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0657 - accuracy: 0.9756 - val_loss: 0.3819 - val_accuracy: 0.9019
# Epoch 23/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0592 - accuracy: 0.9775 - val_loss: 0.3900 - val_accuracy: 0.9049
# Epoch 24/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0612 - accuracy: 0.9766 - val_loss: 0.4245 - val_accuracy: 0.9041
# Epoch 25/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0573 - accuracy: 0.9795 - val_loss: 0.4469 - val_accuracy: 0.8982
# Epoch 26/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0572 - accuracy: 0.9776 - val_loss: 0.4387 - val_accuracy: 0.9042
# Epoch 27/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0509 - accuracy: 0.9802 - val_loss: 0.4713 - val_accuracy: 0.8995
# Epoch 28/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0502 - accuracy: 0.9814 - val_loss: 0.4865 - val_accuracy: 0.8986
# Epoch 29/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0468 - accuracy: 0.9828 - val_loss: 0.4767 - val_accuracy: 0.9031
# Epoch 30/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0453 - accuracy: 0.9825 - val_loss: 0.5186 - val_accuracy: 0.9044
# Epoch 31/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0491 - accuracy: 0.9818 - val_loss: 0.5234 - val_accuracy: 0.9045
# Epoch 32/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0406 - accuracy: 0.9845 - val_loss: 0.5080 - val_accuracy: 0.9032
# Epoch 33/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0378 - accuracy: 0.9865 - val_loss: 0.5356 - val_accuracy: 0.9013
# Epoch 34/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0402 - accuracy: 0.9849 - val_loss: 0.5543 - val_accuracy: 0.9016
# Epoch 35/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0350 - accuracy: 0.9874 - val_loss: 0.5428 - val_accuracy: 0.9006
# Epoch 36/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0375 - accuracy: 0.9857 - val_loss: 0.5498 - val_accuracy: 0.9065
# Epoch 37/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0307 - accuracy: 0.9890 - val_loss: 0.5941 - val_accuracy: 0.9001
# Epoch 38/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0341 - accuracy: 0.9868 - val_loss: 0.5894 - val_accuracy: 0.9051
# Epoch 39/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0337 - accuracy: 0.9874 - val_loss: 0.6088 - val_accuracy: 0.8994
# Epoch 40/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0288 - accuracy: 0.9890 - val_loss: 0.6270 - val_accuracy: 0.9005
# Epoch 41/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0324 - accuracy: 0.9879 - val_loss: 0.6628 - val_accuracy: 0.8987
# Epoch 42/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0333 - accuracy: 0.9870 - val_loss: 0.6470 - val_accuracy: 0.9045
# Epoch 43/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0285 - accuracy: 0.9889 - val_loss: 0.6521 - val_accuracy: 0.9043
# Epoch 44/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0273 - accuracy: 0.9904 - val_loss: 0.6656 - val_accuracy: 0.9017
# Epoch 45/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0245 - accuracy: 0.9917 - val_loss: 0.6868 - val_accuracy: 0.9043
# Epoch 46/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0336 - accuracy: 0.9879 - val_loss: 0.6784 - val_accuracy: 0.9041
# Epoch 47/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0252 - accuracy: 0.9907 - val_loss: 0.6996 - val_accuracy: 0.9009
# Epoch 48/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0272 - accuracy: 0.9902 - val_loss: 0.7444 - val_accuracy: 0.9007
# Epoch 49/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0324 - accuracy: 0.9888 - val_loss: 0.7153 - val_accuracy: 0.9029
# Epoch 50/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0257 - accuracy: 0.9902 - val_loss: 0.7531 - val_accuracy: 0.8978
# Epoch 51/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0247 - accuracy: 0.9913 - val_loss: 0.7698 - val_accuracy: 0.8992
# Epoch 52/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0277 - accuracy: 0.9904 - val_loss: 0.8030 - val_accuracy: 0.8990
# Epoch 53/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0271 - accuracy: 0.9906 - val_loss: 0.7287 - val_accuracy: 0.9046
# Epoch 54/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0199 - accuracy: 0.9928 - val_loss: 0.7505 - val_accuracy: 0.8976
# Epoch 55/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0288 - accuracy: 0.9898 - val_loss: 0.8041 - val_accuracy: 0.8990
# Epoch 56/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0224 - accuracy: 0.9920 - val_loss: 0.8297 - val_accuracy: 0.9019
# Epoch 57/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0235 - accuracy: 0.9919 - val_loss: 0.8075 - val_accuracy: 0.8998
# Epoch 58/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0246 - accuracy: 0.9912 - val_loss: 0.8287 - val_accuracy: 0.9008
# Epoch 59/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0231 - accuracy: 0.9916 - val_loss: 0.7936 - val_accuracy: 0.9000
# Epoch 60/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0273 - accuracy: 0.9901 - val_loss: 0.8305 - val_accuracy: 0.9032
# Epoch 61/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0199 - accuracy: 0.9929 - val_loss: 0.8413 - val_accuracy: 0.9016
# Epoch 62/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0201 - accuracy: 0.9929 - val_loss: 0.8335 - val_accuracy: 0.9027
# Epoch 63/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.8436 - val_accuracy: 0.9055
# Epoch 64/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0192 - accuracy: 0.9933 - val_loss: 0.8448 - val_accuracy: 0.9030
# Epoch 65/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0201 - accuracy: 0.9927 - val_loss: 0.8242 - val_accuracy: 0.9017
# Epoch 66/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0176 - accuracy: 0.9940 - val_loss: 0.8585 - val_accuracy: 0.9030
# Epoch 67/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0185 - accuracy: 0.9936 - val_loss: 0.9112 - val_accuracy: 0.8990
# Epoch 68/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0242 - accuracy: 0.9914 - val_loss: 0.8775 - val_accuracy: 0.8987
# Epoch 69/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0178 - accuracy: 0.9938 - val_loss: 0.9219 - val_accuracy: 0.8991
# Epoch 70/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0197 - accuracy: 0.9925 - val_loss: 0.8446 - val_accuracy: 0.9018
# Epoch 71/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0211 - accuracy: 0.9928 - val_loss: 0.8819 - val_accuracy: 0.9008
# Epoch 72/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0139 - accuracy: 0.9954 - val_loss: 0.9228 - val_accuracy: 0.8974
# Epoch 73/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0224 - accuracy: 0.9922 - val_loss: 0.9120 - val_accuracy: 0.9034
# Epoch 74/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0237 - accuracy: 0.9920 - val_loss: 0.9542 - val_accuracy: 0.9023
# Epoch 75/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0164 - accuracy: 0.9944 - val_loss: 0.9411 - val_accuracy: 0.8963
# Epoch 76/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0225 - accuracy: 0.9930 - val_loss: 0.9340 - val_accuracy: 0.8960
# Epoch 77/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0187 - accuracy: 0.9933 - val_loss: 0.9524 - val_accuracy: 0.9014
# Epoch 78/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0206 - accuracy: 0.9930 - val_loss: 0.9415 - val_accuracy: 0.9016
# Epoch 79/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9942 - val_loss: 0.9633 - val_accuracy: 0.8986
# Epoch 80/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0174 - accuracy: 0.9937 - val_loss: 0.9099 - val_accuracy: 0.9017
# Epoch 81/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0173 - accuracy: 0.9940 - val_loss: 0.9515 - val_accuracy: 0.9008
# Epoch 82/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0207 - accuracy: 0.9932 - val_loss: 1.0041 - val_accuracy: 0.8942
# Epoch 83/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.9856 - val_accuracy: 0.9038
# Epoch 84/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.9806 - val_accuracy: 0.8996
# Epoch 85/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.9870 - val_accuracy: 0.9012
# Epoch 86/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0220 - accuracy: 0.9921 - val_loss: 0.9982 - val_accuracy: 0.9022
# Epoch 87/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0199 - accuracy: 0.9934 - val_loss: 1.0329 - val_accuracy: 0.8993
# Epoch 88/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 1.0844 - val_accuracy: 0.9001
# Epoch 89/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 1.0488 - val_accuracy: 0.8984
# Epoch 90/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0163 - accuracy: 0.9940 - val_loss: 0.9887 - val_accuracy: 0.8971
# Epoch 91/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 1.0926 - val_accuracy: 0.8962
# Epoch 92/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0206 - accuracy: 0.9931 - val_loss: 1.0191 - val_accuracy: 0.8993
# Epoch 93/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0172 - accuracy: 0.9939 - val_loss: 1.0417 - val_accuracy: 0.9035
# Epoch 94/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 1.0350 - val_accuracy: 0.9033
# Epoch 95/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 1.0137 - val_accuracy: 0.9032
# Epoch 96/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0156 - accuracy: 0.9947 - val_loss: 1.0534 - val_accuracy: 0.8989
# Epoch 97/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0170 - accuracy: 0.9944 - val_loss: 1.0669 - val_accuracy: 0.8986
# Epoch 98/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0146 - accuracy: 0.9953 - val_loss: 1.0702 - val_accuracy: 0.8987
# Epoch 99/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0182 - accuracy: 0.9939 - val_loss: 1.0862 - val_accuracy: 0.8988
# Epoch 100/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0236 - accuracy: 0.9936 - val_loss: 1.0398 - val_accuracy: 0.8998

# %% [markdown]
# It's likely gone up to about 97% on the training data and 91% on the validation data.
#
# That's significant, and a step in the right direction!
#
# Try running it for more epochs -- say about 100, and explore the results! But while the results might seem really good, the validation results may actually go down, due to something called 'overfitting' which will be discussed later.
#
# (In a nutshell, 'overfitting' occurs when the network learns the data from the training set really well, but it's too specialised to only that data, and as a result is less effective at seeing *other* data. For example, if all your life you only saw red shoes, then when you see a red shoe you would be very good at identifying it, but blue suade shoes might confuse you...and you know you should never mess with my blue suede shoes.)
#
# Then, look at the code again, and see, step by step how the Convolutions were built:

# %% [markdown]
# Step 1 is to gather the data. You'll notice that there's a bit of a change here in that the training data needed to be reshaped. That's because the first convolution expects a single tensor containing everything, so instead of 60,000 28x28x1 items in a list, we have a single 4D list that is 60,000x28x28x1, and the same for the validation images. If you don't do this, you'll get an error when training as the Convolutions do not recognize the shape.
#
#
#
# ```
# import tensorflow as tf
# mnist = tf.keras.datasets.fashion_mnist
# (training_images, training_labels), (val_images, val_labels) = mnist.load_data()
# training_images=training_images.reshape(60000, 28, 28, 1)
# training_images=training_images / 255.0
# val_images = val_images.reshape(10000, 28, 28, 1)
# val_images=val_images/255.0
# ```

# %% [markdown]
# Next is to define your model. Now instead of the input layer at the top, you're going to add a Convolution. The parameters are:
#
# 1. The number of convolutions you want to generate. Purely arbitrary, but good to start with something in the order of 64
# 2. The size of the Convolution, in this case a 3x3 grid
# 3. The activation function to use -- in this case we'll use relu, which you might recall is the equivalent of returning x when x>0, else returning 0
# 4. In the first layer, the shape of the input data.
#
# You'll follow the Convolution with a MaxPooling layer which is then designed to compress the image, while maintaining the content of the features that were highlighted by the convolution. By specifying (2,2) for the MaxPooling, the effect is to quarter the size of the image. Without going into too much detail here, the idea is that it creates a 2x2 array of pixels, and picks the biggest one, thus turning 4 pixels into 1. It repeats this across the image, and in so doing halves the number of horizontal, and halves the number of vertical pixels, effectively reducing the image to 25% of its original size.
#
# You can call model.summary() to see the size and shape of the network, and you'll notice that after every MaxPooling layer, the image size is reduced in this way.
#
#
# ```
# model = tf.keras.models.Sequential([
#   tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
#   tf.keras.layers.MaxPooling2D(2, 2),
# ```

# %% [markdown]
# Add another convolution
#
#
#
# ```
#   tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
#   tf.keras.layers.MaxPooling2D(2,2)
# ```

# %% [markdown]
# Now flatten the output. After this you'll just have the same DNN structure as the non convolutional version
#
# ```
#   tf.keras.layers.Flatten(),
# ```

# %% [markdown]
# The same 128 dense layers, and 10 output layers as in the pre-convolution example:
#
#
#
# ```
#   tf.keras.layers.Dense(128, activation='relu'),
#   tf.keras.layers.Dense(10, activation='softmax')
# ])
# ```

# %% [markdown]
# Now compile the model, call the fit method to do the training, and evaluate the loss and accuracy from the validation set.
#
#
#
# ```
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# model.fit(training_images, training_labels, epochs=5)
# val_loss, val_acc = model.evaluate(val_images, val_labels)
# print(val_acc)
# ```

# %% [markdown]
# # Optional Additonal Exercises
#
# 1. Try editing the convolutions. Change the 32s to either 16 or 64. Explore what impact this will have on accuracy and/or training time.
#
# 2. Remove the final Convolution. What impact will this have on accuracy or training time?
#
# 3. How about adding more Convolutions? What impact do you think this will have? Experiment with it.
#
# 4. Remove all Convolutions but the first. What impact do you think this will have? Experiment with it.

# %%
import tensorflow as tf

mnist = tf.keras.datasets.fashion_mnist

(training_images, training_labels), (val_images, val_labels) = mnist.load_data()

training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0

val_images=val_images.reshape(10000, 28, 28, 1)
val_images=val_images/255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation="relu", input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3,3), activation="relu"),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(20, activation="relu"),
  tf.keras.layers.Dense(10, activation="softmax")
])

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

model.summary()

model.fit(training_images, training_labels, validation_data=(val_images, val_labels), epochs=20)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                32020
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                210
# =================================================================
# Total params: 51,046
# Trainable params: 51,046
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7293 - accuracy: 0.7402 - val_loss: 0.4050 - val_accuracy: 0.8585
# Epoch 2/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3558 - accuracy: 0.8728 - val_loss: 0.3451 - val_accuracy: 0.8775
# Epoch 3/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3060 - accuracy: 0.8897 - val_loss: 0.3227 - val_accuracy: 0.8861
# Epoch 4/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2707 - accuracy: 0.9024 - val_loss: 0.2959 - val_accuracy: 0.8925
# Epoch 5/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2449 - accuracy: 0.9110 - val_loss: 0.2733 - val_accuracy: 0.9035
# Epoch 6/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2219 - accuracy: 0.9204 - val_loss: 0.2630 - val_accuracy: 0.9044
# Epoch 7/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2043 - accuracy: 0.9253 - val_loss: 0.2653 - val_accuracy: 0.9007
# Epoch 8/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1888 - accuracy: 0.9305 - val_loss: 0.2878 - val_accuracy: 0.9010
# Epoch 9/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1744 - accuracy: 0.9357 - val_loss: 0.2714 - val_accuracy: 0.9019
# Epoch 10/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1637 - accuracy: 0.9401 - val_loss: 0.2749 - val_accuracy: 0.9000
# Epoch 11/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1513 - accuracy: 0.9447 - val_loss: 0.2648 - val_accuracy: 0.9054
# Epoch 12/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1472 - accuracy: 0.9458 - val_loss: 0.3049 - val_accuracy: 0.8993
# Epoch 13/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1361 - accuracy: 0.9500 - val_loss: 0.2938 - val_accuracy: 0.8988
# Epoch 14/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1283 - accuracy: 0.9536 - val_loss: 0.2922 - val_accuracy: 0.9064
# Epoch 15/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1196 - accuracy: 0.9560 - val_loss: 0.2835 - val_accuracy: 0.9121
# Epoch 16/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1142 - accuracy: 0.9583 - val_loss: 0.2961 - val_accuracy: 0.9072
# Epoch 17/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1077 - accuracy: 0.9594 - val_loss: 0.3080 - val_accuracy: 0.9048
# Epoch 18/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1018 - accuracy: 0.9628 - val_loss: 0.3144 - val_accuracy: 0.9073
# Epoch 19/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0963 - accuracy: 0.9647 - val_loss: 0.3158 - val_accuracy: 0.9077
# Epoch 20/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0876 - accuracy: 0.9672 - val_loss: 0.3307 - val_accuracy: 0.9108
