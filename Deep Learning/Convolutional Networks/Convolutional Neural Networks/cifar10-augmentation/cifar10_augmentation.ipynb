# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
# *italicised text*
# In this notebook, we train a CNN on augmented images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)

# %% [markdown]
# ### 6. Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 7. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 8. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 9. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=(x_valid, y_valid),
                    validation_steps=x_valid.shape[0] // batch_size)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
#  - 21s - loss: 1.6879 - accuracy: 0.3847 - val_loss: 1.3854 - val_accuracy: 0.5016
#
# Epoch 00001: val_loss improved from inf to 1.38537, saving model to aug_model.weights.best.hdf5
# Epoch 2/100
#  - 20s - loss: 1.4396 - accuracy: 0.4811 - val_loss: 1.2721 - val_accuracy: 0.5360
#
# Epoch 00002: val_loss improved from 1.38537 to 1.27213, saving model to aug_model.weights.best.hdf5
# Epoch 3/100
#  - 20s - loss: 1.3489 - accuracy: 0.5174 - val_loss: 1.2194 - val_accuracy: 0.5628
#
# Epoch 00003: val_loss improved from 1.27213 to 1.21937, saving model to aug_model.weights.best.hdf5
# Epoch 4/100
#  - 20s - loss: 1.2936 - accuracy: 0.5421 - val_loss: 1.1204 - val_accuracy: 0.6064
#
# Epoch 00004: val_loss improved from 1.21937 to 1.12043, saving model to aug_model.weights.best.hdf5
# Epoch 5/100
#  - 20s - loss: 1.2495 - accuracy: 0.5596 - val_loss: 1.1768 - val_accuracy: 0.5928
#
# Epoch 00005: val_loss did not improve from 1.12043
# Epoch 6/100
#  - 20s - loss: 1.2335 - accuracy: 0.5664 - val_loss: 1.1085 - val_accuracy: 0.6092
#
# Epoch 00006: val_loss improved from 1.12043 to 1.10851, saving model to aug_model.weights.best.hdf5
# Epoch 7/100
#  - 20s - loss: 1.2142 - accuracy: 0.5753 - val_loss: 0.9669 - val_accuracy: 0.6662
#
# Epoch 00007: val_loss improved from 1.10851 to 0.96686, saving model to aug_model.weights.best.hdf5
# Epoch 8/100
#  - 20s - loss: 1.2108 - accuracy: 0.5787 - val_loss: 0.9725 - val_accuracy: 0.6724
#
# Epoch 00008: val_loss did not improve from 0.96686
# Epoch 9/100
#  - 19s - loss: 1.2141 - accuracy: 0.5828 - val_loss: 1.0444 - val_accuracy: 0.6472
#
# Epoch 00009: val_loss did not improve from 0.96686
# Epoch 10/100
#  - 19s - loss: 1.2047 - accuracy: 0.5833 - val_loss: 1.1066 - val_accuracy: 0.6238
#
# Epoch 00010: val_loss did not improve from 0.96686
# Epoch 11/100
#  - 19s - loss: 1.2183 - accuracy: 0.5860 - val_loss: 1.0780 - val_accuracy: 0.6386
#
# Epoch 00011: val_loss did not improve from 0.96686
# Epoch 12/100
#  - 19s - loss: 1.2267 - accuracy: 0.5809 - val_loss: 1.0747 - val_accuracy: 0.6360
#
# Epoch 00012: val_loss did not improve from 0.96686
# Epoch 13/100
#  - 19s - loss: 1.2387 - accuracy: 0.5781 - val_loss: 1.0538 - val_accuracy: 0.6336
#
# Epoch 00013: val_loss did not improve from 0.96686
# Epoch 14/100
#  - 19s - loss: 1.2607 - accuracy: 0.5703 - val_loss: 1.0094 - val_accuracy: 0.6588
#
# Epoch 00014: val_loss did not improve from 0.96686
# Epoch 15/100
#  - 19s - loss: 1.2735 - accuracy: 0.5682 - val_loss: 1.1539 - val_accuracy: 0.6094
#
# Epoch 00015: val_loss did not improve from 0.96686
# Epoch 16/100
#  - 19s - loss: 1.2869 - accuracy: 0.5661 - val_loss: 1.1162 - val_accuracy: 0.6228
#
# Epoch 00016: val_loss did not improve from 0.96686
# Epoch 17/100
#  - 19s - loss: 1.3114 - accuracy: 0.5558 - val_loss: 1.1011 - val_accuracy: 0.6154
#
# Epoch 00017: val_loss did not improve from 0.96686
# Epoch 18/100
#  - 19s - loss: 1.3271 - accuracy: 0.5489 - val_loss: 1.0332 - val_accuracy: 0.6468
#
# Epoch 00018: val_loss did not improve from 0.96686
# Epoch 19/100
#  - 19s - loss: 1.3456 - accuracy: 0.5450 - val_loss: 1.2086 - val_accuracy: 0.5826
#
# Epoch 00019: val_loss did not improve from 0.96686
# Epoch 20/100
#  - 19s - loss: 1.3488 - accuracy: 0.5447 - val_loss: 1.0921 - val_accuracy: 0.6246
#
# Epoch 00020: val_loss did not improve from 0.96686
# Epoch 21/100
#  - 19s - loss: 1.3743 - accuracy: 0.5360 - val_loss: 1.0293 - val_accuracy: 0.6454
#
# Epoch 00021: val_loss did not improve from 0.96686
# Epoch 22/100
#  - 19s - loss: 1.3895 - accuracy: 0.5303 - val_loss: 1.1421 - val_accuracy: 0.6086
#
# Epoch 00022: val_loss did not improve from 0.96686
# Epoch 23/100
#  - 20s - loss: 1.4023 - accuracy: 0.5281 - val_loss: 1.6619 - val_accuracy: 0.5118
#
# Epoch 00023: val_loss did not improve from 0.96686
# Epoch 24/100
#  - 19s - loss: 1.4134 - accuracy: 0.5192 - val_loss: 1.1702 - val_accuracy: 0.5902
#
# Epoch 00024: val_loss did not improve from 0.96686
# Epoch 25/100
#  - 19s - loss: 1.4206 - accuracy: 0.5204 - val_loss: 1.2147 - val_accuracy: 0.5948
#
# Epoch 00025: val_loss did not improve from 0.96686
# Epoch 26/100
#  - 19s - loss: 1.4446 - accuracy: 0.5131 - val_loss: 1.2451 - val_accuracy: 0.5730
#
# Epoch 00026: val_loss did not improve from 0.96686
# Epoch 27/100
#  - 19s - loss: 1.4539 - accuracy: 0.5079 - val_loss: 1.1492 - val_accuracy: 0.6024
#
# Epoch 00027: val_loss did not improve from 0.96686
# Epoch 28/100
#  - 19s - loss: 1.4732 - accuracy: 0.4972 - val_loss: 1.1744 - val_accuracy: 0.5956
#
# Epoch 00028: val_loss did not improve from 0.96686
# Epoch 29/100
#  - 19s - loss: 1.4709 - accuracy: 0.4983 - val_loss: 1.2264 - val_accuracy: 0.5792
#
# Epoch 00029: val_loss did not improve from 0.96686
# Epoch 30/100
#  - 19s - loss: 1.4804 - accuracy: 0.4971 - val_loss: 1.1223 - val_accuracy: 0.6074
#
# Epoch 00030: val_loss did not improve from 0.96686
# Epoch 31/100
#  - 19s - loss: 1.4906 - accuracy: 0.4930 - val_loss: 1.1612 - val_accuracy: 0.6022
#
# Epoch 00031: val_loss did not improve from 0.96686
# Epoch 32/100
#  - 19s - loss: 1.4956 - accuracy: 0.4909 - val_loss: 1.2688 - val_accuracy: 0.5580
#
# Epoch 00032: val_loss did not improve from 0.96686
# Epoch 33/100
#  - 19s - loss: 1.5209 - accuracy: 0.4827 - val_loss: 1.2655 - val_accuracy: 0.5714
#
# Epoch 00033: val_loss did not improve from 0.96686
# Epoch 34/100
#  - 19s - loss: 1.5290 - accuracy: 0.4788 - val_loss: 1.5092 - val_accuracy: 0.4510
#
# Epoch 00034: val_loss did not improve from 0.96686
# Epoch 35/100
#  - 19s - loss: 1.5232 - accuracy: 0.4769 - val_loss: 1.4522 - val_accuracy: 0.4994
#
# Epoch 00035: val_loss did not improve from 0.96686
# Epoch 36/100
#  - 19s - loss: 1.5413 - accuracy: 0.4726 - val_loss: 1.2967 - val_accuracy: 0.5488
#
# Epoch 00036: val_loss did not improve from 0.96686
# Epoch 37/100
#  - 19s - loss: 1.5592 - accuracy: 0.4677 - val_loss: 1.2765 - val_accuracy: 0.5438
#
# Epoch 00037: val_loss did not improve from 0.96686
# Epoch 38/100
#  - 19s - loss: 1.5652 - accuracy: 0.4638 - val_loss: 1.3233 - val_accuracy: 0.5434
#
# Epoch 00038: val_loss did not improve from 0.96686
# Epoch 39/100
#  - 20s - loss: 1.5823 - accuracy: 0.4584 - val_loss: 1.4574 - val_accuracy: 0.4952
#
# Epoch 00039: val_loss did not improve from 0.96686
# Epoch 40/100
#  - 19s - loss: 1.5986 - accuracy: 0.4518 - val_loss: 1.3063 - val_accuracy: 0.5462
#
# Epoch 00040: val_loss did not improve from 0.96686
# Epoch 41/100
#  - 19s - loss: 1.5934 - accuracy: 0.4545 - val_loss: 1.3138 - val_accuracy: 0.5654
#
# Epoch 00041: val_loss did not improve from 0.96686
# Epoch 42/100
#  - 19s - loss: 1.6100 - accuracy: 0.4500 - val_loss: 1.3582 - val_accuracy: 0.5458
#
# Epoch 00042: val_loss did not improve from 0.96686
# Epoch 43/100
#  - 19s - loss: 1.6419 - accuracy: 0.4366 - val_loss: 1.4627 - val_accuracy: 0.4998
#
# Epoch 00043: val_loss did not improve from 0.96686
# Epoch 44/100
#  - 19s - loss: 1.6511 - accuracy: 0.4326 - val_loss: 1.4268 - val_accuracy: 0.5128
#
# Epoch 00044: val_loss did not improve from 0.96686
# Epoch 45/100
#  - 19s - loss: 1.6499 - accuracy: 0.4334 - val_loss: 1.7500 - val_accuracy: 0.4502
#
# Epoch 00045: val_loss did not improve from 0.96686
# Epoch 46/100
#  - 19s - loss: 1.6652 - accuracy: 0.4261 - val_loss: 1.5323 - val_accuracy: 0.4448
#
# Epoch 00046: val_loss did not improve from 0.96686
# Epoch 47/100
#  - 19s - loss: 1.6434 - accuracy: 0.4364 - val_loss: 1.6366 - val_accuracy: 0.4172
#
# Epoch 00047: val_loss did not improve from 0.96686
# Epoch 48/100
#  - 19s - loss: 1.6692 - accuracy: 0.4265 - val_loss: 1.3377 - val_accuracy: 0.5240
#
# Epoch 00048: val_loss did not improve from 0.96686
# Epoch 49/100
#  - 19s - loss: 1.6619 - accuracy: 0.4267 - val_loss: 1.4680 - val_accuracy: 0.4718
#
# Epoch 00049: val_loss did not improve from 0.96686
# Epoch 50/100
#  - 19s - loss: 1.6636 - accuracy: 0.4278 - val_loss: 1.3727 - val_accuracy: 0.5302
#
# Epoch 00050: val_loss did not improve from 0.96686
# Epoch 51/100
#  - 19s - loss: 1.6757 - accuracy: 0.4188 - val_loss: 1.4969 - val_accuracy: 0.4832
#
# Epoch 00051: val_loss did not improve from 0.96686
# Epoch 52/100
#  - 19s - loss: 1.6879 - accuracy: 0.4160 - val_loss: 1.3769 - val_accuracy: 0.5264
#
# Epoch 00052: val_loss did not improve from 0.96686
# Epoch 53/100
#  - 19s - loss: 1.6877 - accuracy: 0.4165 - val_loss: 1.3238 - val_accuracy: 0.5414
#
# Epoch 00053: val_loss did not improve from 0.96686
# Epoch 54/100
#  - 19s - loss: 1.6886 - accuracy: 0.4159 - val_loss: 1.3998 - val_accuracy: 0.4984
#
# Epoch 00054: val_loss did not improve from 0.96686
# Epoch 55/100
#  - 19s - loss: 1.7026 - accuracy: 0.4116 - val_loss: 1.3723 - val_accuracy: 0.5218
#
# Epoch 00055: val_loss did not improve from 0.96686
# Epoch 56/100
#  - 19s - loss: 1.6959 - accuracy: 0.4099 - val_loss: 1.4876 - val_accuracy: 0.5074
#
# Epoch 00056: val_loss did not improve from 0.96686
# Epoch 57/100
#  - 19s - loss: 1.7097 - accuracy: 0.4085 - val_loss: 1.3943 - val_accuracy: 0.5178
#
# Epoch 00057: val_loss did not improve from 0.96686
# Epoch 58/100
#  - 19s - loss: 1.7094 - accuracy: 0.4082 - val_loss: 1.5904 - val_accuracy: 0.4554
#
# Epoch 00058: val_loss did not improve from 0.96686
# Epoch 59/100
#  - 19s - loss: 1.7062 - accuracy: 0.4058 - val_loss: 1.4937 - val_accuracy: 0.4374
#
# Epoch 00059: val_loss did not improve from 0.96686
# Epoch 60/100
#  - 19s - loss: 1.7244 - accuracy: 0.4011 - val_loss: 1.4412 - val_accuracy: 0.5012
#
# Epoch 00060: val_loss did not improve from 0.96686
# Epoch 61/100
#  - 19s - loss: 1.7317 - accuracy: 0.4007 - val_loss: 1.5552 - val_accuracy: 0.4750
#
# Epoch 00061: val_loss did not improve from 0.96686
# Epoch 62/100
#  - 19s - loss: 1.7266 - accuracy: 0.4001 - val_loss: 1.4972 - val_accuracy: 0.4712
#
# Epoch 00062: val_loss did not improve from 0.96686
# Epoch 63/100
#  - 19s - loss: 1.7356 - accuracy: 0.3971 - val_loss: 1.4199 - val_accuracy: 0.5122
#
# Epoch 00063: val_loss did not improve from 0.96686
# Epoch 64/100
#  - 19s - loss: 1.7538 - accuracy: 0.3884 - val_loss: 1.4409 - val_accuracy: 0.5112
#
# Epoch 00064: val_loss did not improve from 0.96686
# Epoch 65/100
#  - 19s - loss: 1.7570 - accuracy: 0.3855 - val_loss: 1.5463 - val_accuracy: 0.4622
#
# Epoch 00065: val_loss did not improve from 0.96686
# Epoch 66/100
#  - 19s - loss: 1.7701 - accuracy: 0.3810 - val_loss: 1.5863 - val_accuracy: 0.4536
#
# Epoch 00066: val_loss did not improve from 0.96686
# Epoch 67/100
#  - 19s - loss: 1.7772 - accuracy: 0.3775 - val_loss: 1.5090 - val_accuracy: 0.4670
#
# Epoch 00067: val_loss did not improve from 0.96686
# Epoch 68/100
#  - 19s - loss: 1.7796 - accuracy: 0.3756 - val_loss: 1.6425 - val_accuracy: 0.3972
#
# Epoch 00068: val_loss did not improve from 0.96686
# Epoch 69/100
#  - 19s - loss: 1.7951 - accuracy: 0.3662 - val_loss: 1.4948 - val_accuracy: 0.4798
#
# Epoch 00069: val_loss did not improve from 0.96686
# Epoch 70/100
#  - 19s - loss: 1.7884 - accuracy: 0.3701 - val_loss: 1.5698 - val_accuracy: 0.4482
#
# Epoch 00070: val_loss did not improve from 0.96686
# Epoch 71/100
#  - 20s - loss: 1.8022 - accuracy: 0.3637 - val_loss: 1.5818 - val_accuracy: 0.4176
#
# Epoch 00071: val_loss did not improve from 0.96686
# Epoch 72/100
#  - 19s - loss: 1.8137 - accuracy: 0.3626 - val_loss: 1.5423 - val_accuracy: 0.4524
#
# Epoch 00072: val_loss did not improve from 0.96686
# Epoch 73/100
#  - 19s - loss: 1.8069 - accuracy: 0.3617 - val_loss: 1.6383 - val_accuracy: 0.4140
#
# Epoch 00073: val_loss did not improve from 0.96686
# Epoch 74/100
#  - 19s - loss: 1.8159 - accuracy: 0.3577 - val_loss: 1.6350 - val_accuracy: 0.4114
#
# Epoch 00074: val_loss did not improve from 0.96686
# Epoch 75/100
#  - 19s - loss: 1.8334 - accuracy: 0.3579 - val_loss: 1.5345 - val_accuracy: 0.4590
#
# Epoch 00075: val_loss did not improve from 0.96686
# Epoch 76/100
#  - 19s - loss: 1.8069 - accuracy: 0.3561 - val_loss: 1.6638 - val_accuracy: 0.4144
#
# Epoch 00076: val_loss did not improve from 0.96686
# Epoch 77/100
#  - 19s - loss: 1.8244 - accuracy: 0.3521 - val_loss: 1.5039 - val_accuracy: 0.4896
#
# Epoch 00077: val_loss did not improve from 0.96686
# Epoch 78/100
#  - 19s - loss: 1.8145 - accuracy: 0.3533 - val_loss: 1.5498 - val_accuracy: 0.4356
#
# Epoch 00078: val_loss did not improve from 0.96686
# Epoch 79/100
#  - 19s - loss: 1.8023 - accuracy: 0.3562 - val_loss: 1.5484 - val_accuracy: 0.4346
#
# Epoch 00079: val_loss did not improve from 0.96686
# Epoch 80/100
#  - 19s - loss: 1.7962 - accuracy: 0.3554 - val_loss: 1.5604 - val_accuracy: 0.4316
#
# Epoch 00080: val_loss did not improve from 0.96686
# Epoch 81/100
#  - 19s - loss: 1.8140 - accuracy: 0.3542 - val_loss: 1.6773 - val_accuracy: 0.4012
#
# Epoch 00081: val_loss did not improve from 0.96686
# Epoch 82/100
#  - 19s - loss: 1.8000 - accuracy: 0.3515 - val_loss: 1.5189 - val_accuracy: 0.4500
#
# Epoch 00082: val_loss did not improve from 0.96686
# Epoch 83/100
#  - 19s - loss: 1.8043 - accuracy: 0.3560 - val_loss: 1.8045 - val_accuracy: 0.3676
#
# Epoch 00083: val_loss did not improve from 0.96686
# Epoch 84/100
#  - 19s - loss: 1.8018 - accuracy: 0.3549 - val_loss: 1.6771 - val_accuracy: 0.4006
#
# Epoch 00084: val_loss did not improve from 0.96686
# Epoch 85/100
#  - 19s - loss: 1.8183 - accuracy: 0.3514 - val_loss: 1.6443 - val_accuracy: 0.3976
#
# Epoch 00085: val_loss did not improve from 0.96686
# Epoch 86/100
#  - 19s - loss: 1.8261 - accuracy: 0.3526 - val_loss: 1.6521 - val_accuracy: 0.3972
#
# Epoch 00086: val_loss did not improve from 0.96686
# Epoch 87/100
#  - 20s - loss: 1.8043 - accuracy: 0.3511 - val_loss: 1.7165 - val_accuracy: 0.3582
#
# Epoch 00087: val_loss did not improve from 0.96686
# Epoch 88/100
#  - 19s - loss: 1.8192 - accuracy: 0.3498 - val_loss: 1.6032 - val_accuracy: 0.4240
#
# Epoch 00088: val_loss did not improve from 0.96686
# Epoch 89/100
#  - 19s - loss: 1.8113 - accuracy: 0.3502 - val_loss: 1.6502 - val_accuracy: 0.3992
#
# Epoch 00089: val_loss did not improve from 0.96686
# Epoch 90/100
#  - 19s - loss: 1.8120 - accuracy: 0.3479 - val_loss: 1.7597 - val_accuracy: 0.3350
#
# Epoch 00090: val_loss did not improve from 0.96686
# Epoch 91/100
#  - 19s - loss: 1.8250 - accuracy: 0.3456 - val_loss: 1.6396 - val_accuracy: 0.4070
#
# Epoch 00091: val_loss did not improve from 0.96686
# Epoch 92/100
#  - 19s - loss: 1.8102 - accuracy: 0.3457 - val_loss: 1.6256 - val_accuracy: 0.4224
#
# Epoch 00092: val_loss did not improve from 0.96686
# Epoch 93/100
#  - 19s - loss: 1.8079 - accuracy: 0.3476 - val_loss: 1.5651 - val_accuracy: 0.4554
#
# Epoch 00093: val_loss did not improve from 0.96686
# Epoch 94/100
#  - 19s - loss: 1.8223 - accuracy: 0.3463 - val_loss: 1.6298 - val_accuracy: 0.4240
#
# Epoch 00094: val_loss did not improve from 0.96686
# Epoch 95/100
#  - 19s - loss: 1.8155 - accuracy: 0.3482 - val_loss: 1.7427 - val_accuracy: 0.3590
#
# Epoch 00095: val_loss did not improve from 0.96686
# Epoch 96/100
#  - 19s - loss: 1.8088 - accuracy: 0.3451 - val_loss: 1.6778 - val_accuracy: 0.3828
#
# Epoch 00096: val_loss did not improve from 0.96686
# Epoch 97/100
#  - 19s - loss: 1.8053 - accuracy: 0.3464 - val_loss: 1.7275 - val_accuracy: 0.3726
#
# Epoch 00097: val_loss did not improve from 0.96686
# Epoch 98/100
#  - 19s - loss: 1.8024 - accuracy: 0.3462 - val_loss: 1.5492 - val_accuracy: 0.4372
#
# Epoch 00098: val_loss did not improve from 0.96686
# Epoch 99/100
#  - 19s - loss: 1.8087 - accuracy: 0.3459 - val_loss: 1.6769 - val_accuracy: 0.3954
#
# Epoch 00099: val_loss did not improve from 0.96686
# Epoch 100/100
#  - 19s - loss: 1.8028 - accuracy: 0.3439 - val_loss: 1.6455 - val_accuracy: 0.4014
#
# Epoch 00100: val_loss did not improve from 0.96686

# %% [markdown]
# ### 10. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# %% [markdown]
# ### 11. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6474999785423279
