# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 32)          8224
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 64)          8256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 500)               32500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 64,534
# Trainable params: 64,534
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Epoch 1/100
# 1407/1407 - 8s - loss: 1.7405 - accuracy: 0.3395 - val_loss: 1.4456 - val_accuracy: 0.4578
#
# Epoch 00001: val_loss improved from inf to 1.44557, saving model to model.weights.best.hdf5
# Epoch 2/100
# 1407/1407 - 4s - loss: 1.4106 - accuracy: 0.4768 - val_loss: 1.3235 - val_accuracy: 0.5098
#
# Epoch 00002: val_loss improved from 1.44557 to 1.32349, saving model to model.weights.best.hdf5
# Epoch 3/100
# 1407/1407 - 4s - loss: 1.2934 - accuracy: 0.5238 - val_loss: 1.2444 - val_accuracy: 0.5454
#
# Epoch 00003: val_loss improved from 1.32349 to 1.24437, saving model to model.weights.best.hdf5
# Epoch 4/100
# 1407/1407 - 4s - loss: 1.2203 - accuracy: 0.5534 - val_loss: 1.1545 - val_accuracy: 0.5760
#
# Epoch 00004: val_loss improved from 1.24437 to 1.15454, saving model to model.weights.best.hdf5
# Epoch 5/100
# 1407/1407 - 4s - loss: 1.1609 - accuracy: 0.5782 - val_loss: 1.0740 - val_accuracy: 0.6090
#
# Epoch 00005: val_loss improved from 1.15454 to 1.07395, saving model to model.weights.best.hdf5
# Epoch 6/100
# 1407/1407 - 4s - loss: 1.1093 - accuracy: 0.5953 - val_loss: 1.0629 - val_accuracy: 0.6060
#
# Epoch 00006: val_loss improved from 1.07395 to 1.06289, saving model to model.weights.best.hdf5
# Epoch 7/100
# 1407/1407 - 4s - loss: 1.0742 - accuracy: 0.6132 - val_loss: 1.0716 - val_accuracy: 0.6190
#
# Epoch 00007: val_loss did not improve from 1.06289
# Epoch 8/100
# 1407/1407 - 4s - loss: 1.0406 - accuracy: 0.6248 - val_loss: 1.0637 - val_accuracy: 0.6112
#
# Epoch 00008: val_loss did not improve from 1.06289
# Epoch 9/100
# 1407/1407 - 4s - loss: 1.0136 - accuracy: 0.6338 - val_loss: 0.9967 - val_accuracy: 0.6476
#
# Epoch 00009: val_loss improved from 1.06289 to 0.99666, saving model to model.weights.best.hdf5
# Epoch 10/100
# 1407/1407 - 4s - loss: 0.9862 - accuracy: 0.6456 - val_loss: 0.9797 - val_accuracy: 0.6522
#
# Epoch 00010: val_loss improved from 0.99666 to 0.97975, saving model to model.weights.best.hdf5
# Epoch 11/100
# 1407/1407 - 4s - loss: 0.9597 - accuracy: 0.6548 - val_loss: 0.9794 - val_accuracy: 0.6524
#
# Epoch 00011: val_loss improved from 0.97975 to 0.97936, saving model to model.weights.best.hdf5
# Epoch 12/100
# 1407/1407 - 4s - loss: 0.9356 - accuracy: 0.6646 - val_loss: 1.0236 - val_accuracy: 0.6452
#
# Epoch 00012: val_loss did not improve from 0.97936
# Epoch 13/100
# 1407/1407 - 4s - loss: 0.9166 - accuracy: 0.6709 - val_loss: 1.0037 - val_accuracy: 0.6418
#
# Epoch 00013: val_loss did not improve from 0.97936
# Epoch 14/100
# 1407/1407 - 4s - loss: 0.9018 - accuracy: 0.6748 - val_loss: 0.9373 - val_accuracy: 0.6694
#
# Epoch 00014: val_loss improved from 0.97936 to 0.93729, saving model to model.weights.best.hdf5
# Epoch 15/100
# 1407/1407 - 4s - loss: 0.8823 - accuracy: 0.6841 - val_loss: 0.9456 - val_accuracy: 0.6666
#
# Epoch 00015: val_loss did not improve from 0.93729
# Epoch 16/100
# 1407/1407 - 4s - loss: 0.8700 - accuracy: 0.6904 - val_loss: 0.9645 - val_accuracy: 0.6594
#
# Epoch 00016: val_loss did not improve from 0.93729
# Epoch 17/100
# 1407/1407 - 4s - loss: 0.8619 - accuracy: 0.6892 - val_loss: 0.9279 - val_accuracy: 0.6772
#
# Epoch 00017: val_loss improved from 0.93729 to 0.92787, saving model to model.weights.best.hdf5
# Epoch 18/100
# 1407/1407 - 4s - loss: 0.8464 - accuracy: 0.6985 - val_loss: 0.9217 - val_accuracy: 0.6822
#
# Epoch 00018: val_loss improved from 0.92787 to 0.92169, saving model to model.weights.best.hdf5
# Epoch 19/100
# 1407/1407 - 4s - loss: 0.8289 - accuracy: 0.7030 - val_loss: 0.9333 - val_accuracy: 0.6732
#
# Epoch 00019: val_loss did not improve from 0.92169
# Epoch 20/100
# 1407/1407 - 4s - loss: 0.8248 - accuracy: 0.7049 - val_loss: 0.9674 - val_accuracy: 0.6618
#
# Epoch 00020: val_loss did not improve from 0.92169
# Epoch 21/100
# 1407/1407 - 4s - loss: 0.8058 - accuracy: 0.7096 - val_loss: 0.9296 - val_accuracy: 0.6778
#
# Epoch 00021: val_loss did not improve from 0.92169
# Epoch 22/100
# 1407/1407 - 4s - loss: 0.7990 - accuracy: 0.7145 - val_loss: 0.9200 - val_accuracy: 0.6848
#
# Epoch 00022: val_loss improved from 0.92169 to 0.92001, saving model to model.weights.best.hdf5
# Epoch 23/100
# 1407/1407 - 4s - loss: 0.7947 - accuracy: 0.7150 - val_loss: 0.9625 - val_accuracy: 0.6654
#
# Epoch 00023: val_loss did not improve from 0.92001
# Epoch 24/100
# 1407/1407 - 4s - loss: 0.7901 - accuracy: 0.7168 - val_loss: 0.9727 - val_accuracy: 0.6526
#
# Epoch 00024: val_loss did not improve from 0.92001
# Epoch 25/100
# 1407/1407 - 4s - loss: 0.7777 - accuracy: 0.7224 - val_loss: 0.9365 - val_accuracy: 0.6714
#
# Epoch 00025: val_loss did not improve from 0.92001
# Epoch 26/100
# 1407/1407 - 4s - loss: 0.7635 - accuracy: 0.7276 - val_loss: 0.9301 - val_accuracy: 0.6836
#
# Epoch 00026: val_loss did not improve from 0.92001
# Epoch 27/100
# 1407/1407 - 4s - loss: 0.7567 - accuracy: 0.7286 - val_loss: 0.9321 - val_accuracy: 0.6738
#
# Epoch 00027: val_loss did not improve from 0.92001
# Epoch 28/100
# 1407/1407 - 4s - loss: 0.7539 - accuracy: 0.7300 - val_loss: 0.9520 - val_accuracy: 0.6710
#
# Epoch 00028: val_loss did not improve from 0.92001
# Epoch 29/100
# 1407/1407 - 4s - loss: 0.7470 - accuracy: 0.7333 - val_loss: 0.9176 - val_accuracy: 0.6818
#
# Epoch 00029: val_loss improved from 0.92001 to 0.91764, saving model to model.weights.best.hdf5
# Epoch 30/100
# 1407/1407 - 4s - loss: 0.7425 - accuracy: 0.7357 - val_loss: 0.9031 - val_accuracy: 0.6858
#
# Epoch 00030: val_loss improved from 0.91764 to 0.90309, saving model to model.weights.best.hdf5
# Epoch 31/100
# 1407/1407 - 4s - loss: 0.7334 - accuracy: 0.7373 - val_loss: 0.9223 - val_accuracy: 0.6846
#
# Epoch 00031: val_loss did not improve from 0.90309
# Epoch 32/100
# 1407/1407 - 4s - loss: 0.7263 - accuracy: 0.7407 - val_loss: 0.9551 - val_accuracy: 0.6702
#
# Epoch 00032: val_loss did not improve from 0.90309
# Epoch 33/100
# 1407/1407 - 4s - loss: 0.7252 - accuracy: 0.7402 - val_loss: 0.9361 - val_accuracy: 0.6814
#
# Epoch 00033: val_loss did not improve from 0.90309
# Epoch 34/100
# 1407/1407 - 4s - loss: 0.7169 - accuracy: 0.7436 - val_loss: 0.9392 - val_accuracy: 0.6764
#
# Epoch 00034: val_loss did not improve from 0.90309
# Epoch 35/100
# 1407/1407 - 4s - loss: 0.7116 - accuracy: 0.7446 - val_loss: 0.9153 - val_accuracy: 0.6866
#
# Epoch 00035: val_loss did not improve from 0.90309
# Epoch 36/100
# 1407/1407 - 4s - loss: 0.7036 - accuracy: 0.7477 - val_loss: 0.9080 - val_accuracy: 0.6924
#
# Epoch 00036: val_loss did not improve from 0.90309
# Epoch 37/100
# 1407/1407 - 4s - loss: 0.6994 - accuracy: 0.7488 - val_loss: 0.9239 - val_accuracy: 0.6876
#
# Epoch 00037: val_loss did not improve from 0.90309
# Epoch 38/100
# 1407/1407 - 4s - loss: 0.6977 - accuracy: 0.7506 - val_loss: 0.9328 - val_accuracy: 0.6848
#
# Epoch 00038: val_loss did not improve from 0.90309
# Epoch 39/100
# 1407/1407 - 4s - loss: 0.6971 - accuracy: 0.7520 - val_loss: 0.9547 - val_accuracy: 0.6846
#
# Epoch 00039: val_loss did not improve from 0.90309
# Epoch 40/100
# 1407/1407 - 4s - loss: 0.6897 - accuracy: 0.7539 - val_loss: 0.9154 - val_accuracy: 0.6944
#
# Epoch 00040: val_loss did not improve from 0.90309
# Epoch 41/100
# 1407/1407 - 4s - loss: 0.6827 - accuracy: 0.7570 - val_loss: 0.9222 - val_accuracy: 0.6910
#
# Epoch 00041: val_loss did not improve from 0.90309
# Epoch 42/100
# 1407/1407 - 4s - loss: 0.6754 - accuracy: 0.7584 - val_loss: 0.9117 - val_accuracy: 0.6930
#
# Epoch 00042: val_loss did not improve from 0.90309
# Epoch 43/100
# 1407/1407 - 4s - loss: 0.6740 - accuracy: 0.7591 - val_loss: 0.9214 - val_accuracy: 0.6882
#
# Epoch 00043: val_loss did not improve from 0.90309
# Epoch 44/100
# 1407/1407 - 4s - loss: 0.6733 - accuracy: 0.7596 - val_loss: 0.9184 - val_accuracy: 0.6890
#
# Epoch 00044: val_loss did not improve from 0.90309
# Epoch 45/100
# 1407/1407 - 4s - loss: 0.6683 - accuracy: 0.7631 - val_loss: 0.9335 - val_accuracy: 0.6810
#
# Epoch 00045: val_loss did not improve from 0.90309
# Epoch 46/100
# 1407/1407 - 4s - loss: 0.6649 - accuracy: 0.7631 - val_loss: 0.9434 - val_accuracy: 0.6818
#
# Epoch 00046: val_loss did not improve from 0.90309
# Epoch 47/100
# 1407/1407 - 4s - loss: 0.6667 - accuracy: 0.7615 - val_loss: 0.9193 - val_accuracy: 0.6932
#
# Epoch 00047: val_loss did not improve from 0.90309
# Epoch 48/100
# 1407/1407 - 4s - loss: 0.6516 - accuracy: 0.7660 - val_loss: 0.9341 - val_accuracy: 0.6810
#
# Epoch 00048: val_loss did not improve from 0.90309
# Epoch 49/100
# 1407/1407 - 4s - loss: 0.6579 - accuracy: 0.7646 - val_loss: 0.9741 - val_accuracy: 0.6730
#
# Epoch 00049: val_loss did not improve from 0.90309
# Epoch 50/100
# 1407/1407 - 4s - loss: 0.6509 - accuracy: 0.7663 - val_loss: 0.9562 - val_accuracy: 0.6874
#
# Epoch 00050: val_loss did not improve from 0.90309
# Epoch 51/100
# 1407/1407 - 4s - loss: 0.6467 - accuracy: 0.7672 - val_loss: 0.9281 - val_accuracy: 0.6854
#
# Epoch 00051: val_loss did not improve from 0.90309
# Epoch 52/100
# 1407/1407 - 4s - loss: 0.6431 - accuracy: 0.7674 - val_loss: 0.9382 - val_accuracy: 0.6840
#
# Epoch 00052: val_loss did not improve from 0.90309
# Epoch 53/100
# 1407/1407 - 4s - loss: 0.6435 - accuracy: 0.7691 - val_loss: 0.9014 - val_accuracy: 0.7002
#
# Epoch 00053: val_loss improved from 0.90309 to 0.90145, saving model to model.weights.best.hdf5
# Epoch 54/100
# 1407/1407 - 4s - loss: 0.6410 - accuracy: 0.7697 - val_loss: 0.9337 - val_accuracy: 0.6836
#
# Epoch 00054: val_loss did not improve from 0.90145
# Epoch 55/100
# 1407/1407 - 4s - loss: 0.6391 - accuracy: 0.7705 - val_loss: 0.9571 - val_accuracy: 0.6838
#
# Epoch 00055: val_loss did not improve from 0.90145
# Epoch 56/100
# 1407/1407 - 4s - loss: 0.6285 - accuracy: 0.7751 - val_loss: 0.9964 - val_accuracy: 0.6680
#
# Epoch 00056: val_loss did not improve from 0.90145
# Epoch 57/100
# 1407/1407 - 4s - loss: 0.6317 - accuracy: 0.7742 - val_loss: 0.9595 - val_accuracy: 0.6858
#
# Epoch 00057: val_loss did not improve from 0.90145
# Epoch 58/100
# 1407/1407 - 4s - loss: 0.6237 - accuracy: 0.7770 - val_loss: 0.9622 - val_accuracy: 0.6844
#
# Epoch 00058: val_loss did not improve from 0.90145
# Epoch 59/100
# 1407/1407 - 4s - loss: 0.6209 - accuracy: 0.7774 - val_loss: 0.9284 - val_accuracy: 0.6900
#
# Epoch 00059: val_loss did not improve from 0.90145
# Epoch 60/100
# 1407/1407 - 4s - loss: 0.6204 - accuracy: 0.7790 - val_loss: 1.0121 - val_accuracy: 0.6670
#
# Epoch 00060: val_loss did not improve from 0.90145
# Epoch 61/100
# 1407/1407 - 4s - loss: 0.6282 - accuracy: 0.7756 - val_loss: 0.9267 - val_accuracy: 0.6920
#
# Epoch 00061: val_loss did not improve from 0.90145
# Epoch 62/100
# 1407/1407 - 4s - loss: 0.6126 - accuracy: 0.7808 - val_loss: 0.9536 - val_accuracy: 0.6820
#
# Epoch 00062: val_loss did not improve from 0.90145
# Epoch 63/100
# 1407/1407 - 4s - loss: 0.6180 - accuracy: 0.7804 - val_loss: 0.9736 - val_accuracy: 0.6696
#
# Epoch 00063: val_loss did not improve from 0.90145
# Epoch 64/100
# 1407/1407 - 4s - loss: 0.6170 - accuracy: 0.7796 - val_loss: 0.9799 - val_accuracy: 0.6776
#
# Epoch 00064: val_loss did not improve from 0.90145
# Epoch 65/100
# 1407/1407 - 4s - loss: 0.6113 - accuracy: 0.7809 - val_loss: 0.9713 - val_accuracy: 0.6804
#
# Epoch 00065: val_loss did not improve from 0.90145
# Epoch 66/100
# 1407/1407 - 4s - loss: 0.6078 - accuracy: 0.7838 - val_loss: 0.9607 - val_accuracy: 0.6864
#
# Epoch 00066: val_loss did not improve from 0.90145
# Epoch 67/100
# 1407/1407 - 4s - loss: 0.6057 - accuracy: 0.7829 - val_loss: 0.9546 - val_accuracy: 0.6848
#
# Epoch 00067: val_loss did not improve from 0.90145
# Epoch 68/100
# 1407/1407 - 4s - loss: 0.6083 - accuracy: 0.7823 - val_loss: 0.9695 - val_accuracy: 0.6882
#
# Epoch 00068: val_loss did not improve from 0.90145
# Epoch 69/100
# 1407/1407 - 4s - loss: 0.5982 - accuracy: 0.7854 - val_loss: 0.9477 - val_accuracy: 0.6856
#
# Epoch 00069: val_loss did not improve from 0.90145
# Epoch 70/100
# 1407/1407 - 4s - loss: 0.5980 - accuracy: 0.7852 - val_loss: 0.9598 - val_accuracy: 0.6864
#
# Epoch 00070: val_loss did not improve from 0.90145
# Epoch 71/100
# 1407/1407 - 4s - loss: 0.5970 - accuracy: 0.7865 - val_loss: 0.9701 - val_accuracy: 0.6832
#
# Epoch 00071: val_loss did not improve from 0.90145
# Epoch 72/100
# 1407/1407 - 4s - loss: 0.5933 - accuracy: 0.7869 - val_loss: 0.9865 - val_accuracy: 0.6806
#
# Epoch 00072: val_loss did not improve from 0.90145
# Epoch 73/100
# 1407/1407 - 4s - loss: 0.5959 - accuracy: 0.7877 - val_loss: 0.9570 - val_accuracy: 0.6790
#
# Epoch 00073: val_loss did not improve from 0.90145
# Epoch 74/100
# 1407/1407 - 4s - loss: 0.5895 - accuracy: 0.7881 - val_loss: 0.9733 - val_accuracy: 0.6836
#
# Epoch 00074: val_loss did not improve from 0.90145
# Epoch 75/100
# 1407/1407 - 4s - loss: 0.5906 - accuracy: 0.7857 - val_loss: 0.9733 - val_accuracy: 0.6806
#
# Epoch 00075: val_loss did not improve from 0.90145
# Epoch 76/100
# 1407/1407 - 4s - loss: 0.5844 - accuracy: 0.7901 - val_loss: 0.9705 - val_accuracy: 0.6850
#
# Epoch 00076: val_loss did not improve from 0.90145
# Epoch 77/100
# 1407/1407 - 4s - loss: 0.5885 - accuracy: 0.7898 - val_loss: 0.9808 - val_accuracy: 0.6686
#
# Epoch 00077: val_loss did not improve from 0.90145
# Epoch 78/100
# 1407/1407 - 4s - loss: 0.5870 - accuracy: 0.7898 - val_loss: 0.9815 - val_accuracy: 0.6724
#
# Epoch 00078: val_loss did not improve from 0.90145
# Epoch 79/100
# 1407/1407 - 4s - loss: 0.5842 - accuracy: 0.7920 - val_loss: 0.9662 - val_accuracy: 0.6790
#
# Epoch 00079: val_loss did not improve from 0.90145
# Epoch 80/100
# 1407/1407 - 4s - loss: 0.5845 - accuracy: 0.7924 - val_loss: 0.9586 - val_accuracy: 0.6938
#
# Epoch 00080: val_loss did not improve from 0.90145
# Epoch 81/100
# 1407/1407 - 4s - loss: 0.5796 - accuracy: 0.7926 - val_loss: 0.9511 - val_accuracy: 0.6910
#
# Epoch 00081: val_loss did not improve from 0.90145
# Epoch 82/100
# 1407/1407 - 4s - loss: 0.5789 - accuracy: 0.7936 - val_loss: 0.9756 - val_accuracy: 0.6838
#
# Epoch 00082: val_loss did not improve from 0.90145
# Epoch 83/100
# 1407/1407 - 4s - loss: 0.5748 - accuracy: 0.7946 - val_loss: 1.0027 - val_accuracy: 0.6784
#
# Epoch 00083: val_loss did not improve from 0.90145
# Epoch 84/100
# 1407/1407 - 4s - loss: 0.5762 - accuracy: 0.7929 - val_loss: 1.0102 - val_accuracy: 0.6724
#
# Epoch 00084: val_loss did not improve from 0.90145
# Epoch 85/100
# 1407/1407 - 4s - loss: 0.5685 - accuracy: 0.7973 - val_loss: 0.9797 - val_accuracy: 0.6816
#
# Epoch 00085: val_loss did not improve from 0.90145
# Epoch 86/100
# 1407/1407 - 4s - loss: 0.5691 - accuracy: 0.7977 - val_loss: 0.9806 - val_accuracy: 0.6780
#
# Epoch 00086: val_loss did not improve from 0.90145
# Epoch 87/100
# 1407/1407 - 4s - loss: 0.5682 - accuracy: 0.7991 - val_loss: 0.9864 - val_accuracy: 0.6900
#
# Epoch 00087: val_loss did not improve from 0.90145
# Epoch 88/100
# 1407/1407 - 4s - loss: 0.5795 - accuracy: 0.7928 - val_loss: 1.0172 - val_accuracy: 0.6734
#
# Epoch 00088: val_loss did not improve from 0.90145
# Epoch 89/100
# 1407/1407 - 4s - loss: 0.5645 - accuracy: 0.7983 - val_loss: 0.9692 - val_accuracy: 0.6916
#
# Epoch 00089: val_loss did not improve from 0.90145
# Epoch 90/100
# 1407/1407 - 4s - loss: 0.5643 - accuracy: 0.7992 - val_loss: 0.9861 - val_accuracy: 0.6838
#
# Epoch 00090: val_loss did not improve from 0.90145
# Epoch 91/100
# 1407/1407 - 4s - loss: 0.5642 - accuracy: 0.7983 - val_loss: 0.9905 - val_accuracy: 0.6886
#
# Epoch 00091: val_loss did not improve from 0.90145
# Epoch 92/100
# 1407/1407 - 4s - loss: 0.5658 - accuracy: 0.7988 - val_loss: 0.9891 - val_accuracy: 0.6738
#
# Epoch 00092: val_loss did not improve from 0.90145
# Epoch 93/100
# 1407/1407 - 4s - loss: 0.5617 - accuracy: 0.8002 - val_loss: 0.9968 - val_accuracy: 0.6876
#
# Epoch 00093: val_loss did not improve from 0.90145
# Epoch 94/100
# 1407/1407 - 4s - loss: 0.5560 - accuracy: 0.8013 - val_loss: 1.0441 - val_accuracy: 0.6838
#
# Epoch 00094: val_loss did not improve from 0.90145
# Epoch 95/100
# 1407/1407 - 4s - loss: 0.5583 - accuracy: 0.7990 - val_loss: 1.0051 - val_accuracy: 0.6814
#
# Epoch 00095: val_loss did not improve from 0.90145
# Epoch 96/100
# 1407/1407 - 4s - loss: 0.5555 - accuracy: 0.8017 - val_loss: 1.0046 - val_accuracy: 0.6764
#
# Epoch 00096: val_loss did not improve from 0.90145
# Epoch 97/100
# 1407/1407 - 4s - loss: 0.5530 - accuracy: 0.8044 - val_loss: 1.0141 - val_accuracy: 0.6784
#
# Epoch 00097: val_loss did not improve from 0.90145
# Epoch 98/100
# 1407/1407 - 4s - loss: 0.5505 - accuracy: 0.8037 - val_loss: 1.0216 - val_accuracy: 0.6788
#
# Epoch 00098: val_loss did not improve from 0.90145
# Epoch 99/100
# 1407/1407 - 4s - loss: 0.5568 - accuracy: 0.8012 - val_loss: 0.9972 - val_accuracy: 0.6830
#
# Epoch 00099: val_loss did not improve from 0.90145
# Epoch 100/100
# 1407/1407 - 4s - loss: 0.5477 - accuracy: 0.8031 - val_loss: 1.0191 - val_accuracy: 0.6844
#
# Epoch 00100: val_loss did not improve from 0.90145

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6825000047683716

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
